# %%
from llama_stack_client import LlamaStackClient

client = LlamaStackClient(
    base_url="http://lls-route-model-namespace.apps.rosa.trustyai-rob.4osv.p3.openshiftapps.com"

)

# %%
client.models.list()
# Out:
# [Model(identifier=None, metadata=None, api_model_type=None, provider_id=None, provider_resource_id=None, type=None, id='vllm-qwen/qwen3', object='model', created=1768827461, owned_by='llama_stack', custom_metadata={'model_type': 'llm', 'provider_id': 'vllm-qwen', 'provider_resource_id': 'qwen3'}),
#  Model(identifier=None, metadata=None, api_model_type=None, provider_id=None, provider_resource_id=None, type=None, id='vllm-tokenizer/minilm', object='model', created=1768827461, owned_by='llama_stack', custom_metadata={'model_type': 'llm', 'provider_id': 'vllm-tokenizer', 'provider_resource_id': 'minilm'})]
